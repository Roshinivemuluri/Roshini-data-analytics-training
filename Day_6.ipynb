# %% [markdown]
# <a href="https://colab.research.google.com/github/Roshinivemuluri/Roshini-data-analytics-training/blob/main/Day_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
x=pd.read_csv('/content/station_day.csv.zip')

# %%
x
# Out:
#        StationId        Date  PM2.5    PM10     NO     NO2     NOx    NH3  \
# 0          AP001  2017-11-24  71.36  115.75   1.75   20.65   12.40  12.19
# 1          AP001  2017-11-25  81.40  124.50   1.44   20.50   12.08  10.72
# 2          AP001  2017-11-26  78.32  129.06   1.26   26.00   14.85  10.28
# 3          AP001  2017-11-27  88.76  135.32   6.60   30.85   21.77  12.91
# 4          AP001  2017-11-28  64.18  104.09   2.56   28.07   17.01  11.42
# ...          ...         ...    ...     ...    ...     ...     ...    ...
# 108030     WB013  2020-06-27   8.65   16.46    NaN     NaN     NaN    NaN
# 108031     WB013  2020-06-28  11.80   18.47    NaN     NaN     NaN    NaN
# 108032     WB013  2020-06-29  18.60   32.26  13.65  200.87  214.20  11.40
# 108033     WB013  2020-06-30  16.07   39.30   7.56   29.13   36.69  29.26
# 108034     WB013  2020-07-01  10.50   36.50   7.78   22.50   30.25  27.23
#
#           CO    SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# ...

# %%
import matplotlib.pyplot as plt

x_values=x['O3']
y_values=x['PM2.5']

plt.scatter(x_values,y_values)

# %%
plt.plot(x_values, y_values)

# %%
import seaborn as sns

# %%
sns.scatterplot(x=x_values, y=y_values)
# Out:
# <Axes: xlabel='O3', ylabel='PM2.5'>

# %%
sns.histplot(x=y_values)  # Histogram of Q19 values
# Out:
# <Axes: xlabel='PM2.5', ylabel='Count'>

# %%
sns.barplot(x=x_values, y=y_values)
plt.show()

# %%
sns.lineplot(x=x_values, y=y_values)
# Out:
# <Axes: >

# %%
import scipy.stats as stats
# Number of trials
n = 10

# Probability of success
p = 0.5

# Calculate x-axis values (number of successes from 0 to n)
x_values = np.arange(0, n + 1)

# Calculate PMF directly using binom.pmf
y_values = stats.binom.pmf(x_values, n, p)

# Create the plot
plt.bar(x_values, y_values)
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title('Binomial Distribution PMF')
plt.show()

# %%
# prompt: print random numbers in binomial distribution

import numpy as np

# Number of trials
n = 10

# Probability of success
p = 0.5

# Generate 10 random numbers from a binomial distribution
random_numbers = np.random.binomial(n, p, 10)

random_numbers
# Out:
# array([6, 5, 6, 8, 6, 3, 3, 5, 6, 6])

# %%
import seaborn as sns

import pandas as pd

import numpy as np



# Sample DataFrame

df = pd.DataFrame(np.random.randn(10, 5), columns=['A', 'B', 'C', 'D', 'E'])



corr_matrix = df.corr()

sns.heatmap(corr_matrix, annot=True)

plt.title('Correlation Matrix')

plt.show()
