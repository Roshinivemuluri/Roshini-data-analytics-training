# %% [markdown]
# <a href="https://colab.research.google.com/github/Roshinivemuluri/Roshini-data-analytics-training/blob/main/Day-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
x=pd.read_csv('/content/station_day.csv.zip')

# %%
x
# Out:
#        StationId        Date  PM2.5    PM10     NO     NO2     NOx    NH3  \
# 0          AP001  2017-11-24  71.36  115.75   1.75   20.65   12.40  12.19
# 1          AP001  2017-11-25  81.40  124.50   1.44   20.50   12.08  10.72
# 2          AP001  2017-11-26  78.32  129.06   1.26   26.00   14.85  10.28
# 3          AP001  2017-11-27  88.76  135.32   6.60   30.85   21.77  12.91
# 4          AP001  2017-11-28  64.18  104.09   2.56   28.07   17.01  11.42
# ...          ...         ...    ...     ...    ...     ...     ...    ...
# 108030     WB013  2020-06-27   8.65   16.46    NaN     NaN     NaN    NaN
# 108031     WB013  2020-06-28  11.80   18.47    NaN     NaN     NaN    NaN
# 108032     WB013  2020-06-29  18.60   32.26  13.65  200.87  214.20  11.40
# 108033     WB013  2020-06-30  16.07   39.30   7.56   29.13   36.69  29.26
# 108034     WB013  2020-07-01  10.50   36.50   7.78   22.50   30.25  27.23
#
#           CO    SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# ...

# %%
x.isnull().sum()
# Out:
# StationId         0
# Date              0
# PM2.5         21625
# PM10          42706
# NO            17106
# NO2           16547
# NOx           15500
# NH3           48105
# CO            12998
# SO2           25204
# O3            25568
# Benzene       31455
# Toluene       38702
# Xylene        85137
# AQI           21010
# AQI_Bucket    21010
# dtype: int64

# %%
missing_values=['N/a','na',np.nan]
x=pd.read_csv('/content/station_day.csv.zip',na_values=missing_values)

# %%
x.isnull()
# Out:
#         StationId   Date  PM2.5   PM10     NO    NO2    NOx    NH3     CO  \
# 0           False  False  False  False  False  False  False  False  False
# 1           False  False  False  False  False  False  False  False  False
# 2           False  False  False  False  False  False  False  False  False
# 3           False  False  False  False  False  False  False  False  False
# 4           False  False  False  False  False  False  False  False  False
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 108030      False  False  False  False   True   True   True   True  False
# 108031      False  False  False  False   True   True   True   True  False
# 108032      False  False  False  False  False  False  False  False  False
# 108033      False  False  False  False  False  False  False  False  False
# 108034      False  False  False  False  False  False  False  False  False
#
#           SO2     O3  Benzene  Toluene  Xylene    AQI  AQI_Bucket
# ...

# %%
x.isnull().sum()
# Out:
# StationId         0
# Date              0
# PM2.5         21625
# PM10          42706
# NO            17106
# NO2           16547
# NOx           15500
# NH3           48105
# CO            12998
# SO2           25204
# O3            25568
# Benzene       31455
# Toluene       38702
# Xylene        85137
# AQI           21010
# AQI_Bucket    21010
# dtype: int64

# %%
x.isnull().any()
# Out:
# StationId     False
# Date          False
# PM2.5          True
# PM10           True
# NO             True
# NO2            True
# NOx            True
# NH3            True
# CO             True
# SO2            True
# O3             True
# Benzene        True
# Toluene        True
# Xylene         True
# AQI            True
# AQI_Bucket     True
# dtype: bool

# %%
x.mean(numeric_only=True)
# Out:
# PM2.5       80.272571
# PM10       157.968427
# NO          23.123424
# NO2         35.240760
# NOx         41.195055
# NH3         28.732875
# CO           1.605749
# SO2         12.257634
# O3          38.134836
# Benzene      3.358029
# Toluene     15.345394
# Xylene       2.423446
# AQI        179.749290
# dtype: float64

# %%
x.fillna(x.mean(numeric_only=True))
# Out:
#        StationId        Date  PM2.5    PM10         NO        NO2         NOx  \
# 0          AP001  2017-11-24  71.36  115.75   1.750000   20.65000   12.400000
# 1          AP001  2017-11-25  81.40  124.50   1.440000   20.50000   12.080000
# 2          AP001  2017-11-26  78.32  129.06   1.260000   26.00000   14.850000
# 3          AP001  2017-11-27  88.76  135.32   6.600000   30.85000   21.770000
# 4          AP001  2017-11-28  64.18  104.09   2.560000   28.07000   17.010000
# ...          ...         ...    ...     ...        ...        ...         ...
# 108030     WB013  2020-06-27   8.65   16.46  23.123424   35.24076   41.195055
# 108031     WB013  2020-06-28  11.80   18.47  23.123424   35.24076   41.195055
# 108032     WB013  2020-06-29  18.60   32.26  13.650000  200.87000  214.200000
# 108033     WB013  2020-06-30  16.07   39.30   7.560000   29.13000   36.690000
# 108034     WB013  2020-07-01  10.50   36.50   7.780000   22.50000   30.250000
#
# ...

# %%
x.mode()
# Out:
#     StationId        Date  PM2.5   PM10   NO  NO2  NOx    NH3   CO  SO2  \
# 0       DL007  2020-03-11   11.0  71.05  2.5  9.0  0.0  13.42  0.0  3.4
# 1       DL008  2020-03-12    NaN  71.88  NaN  NaN  NaN    NaN  NaN  NaN
# 2       DL013  2020-03-13    NaN  94.00  NaN  NaN  NaN    NaN  NaN  NaN
# 3       DL021  2020-03-14    NaN    NaN  NaN  NaN  NaN    NaN  NaN  NaN
# 4       DL033  2020-03-15    NaN    NaN  NaN  NaN  NaN    NaN  NaN  NaN
# ..        ...         ...    ...    ...  ...  ...  ...    ...  ...  ...
# 108       NaN  2020-06-27    NaN    NaN  NaN  NaN  NaN    NaN  NaN  NaN
# 109       NaN  2020-06-28    NaN    NaN  NaN  NaN  NaN    NaN  NaN  NaN
# 110       NaN  2020-06-29    NaN    NaN  NaN  NaN  NaN    NaN  NaN  NaN
# 111       NaN  2020-06-30    NaN    NaN  NaN  NaN  NaN    NaN  NaN  NaN
# 112       NaN  2020-07-01    NaN    NaN  NaN  NaN  NaN    NaN  NaN  NaN
#
#         O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# ...

# %%
x.fillna(x.mode())
# Out:
#        StationId        Date  PM2.5    PM10     NO     NO2     NOx    NH3  \
# 0          AP001  2017-11-24  71.36  115.75   1.75   20.65   12.40  12.19
# 1          AP001  2017-11-25  81.40  124.50   1.44   20.50   12.08  10.72
# 2          AP001  2017-11-26  78.32  129.06   1.26   26.00   14.85  10.28
# 3          AP001  2017-11-27  88.76  135.32   6.60   30.85   21.77  12.91
# 4          AP001  2017-11-28  64.18  104.09   2.56   28.07   17.01  11.42
# ...          ...         ...    ...     ...    ...     ...     ...    ...
# 108030     WB013  2020-06-27   8.65   16.46    NaN     NaN     NaN    NaN
# 108031     WB013  2020-06-28  11.80   18.47    NaN     NaN     NaN    NaN
# 108032     WB013  2020-06-29  18.60   32.26  13.65  200.87  214.20  11.40
# 108033     WB013  2020-06-30  16.07   39.30   7.56   29.13   36.69  29.26
# 108034     WB013  2020-07-01  10.50   36.50   7.78   22.50   30.25  27.23
#
#           CO    SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# ...

# %%
x.select_dtypes(include=['float64']).median()
# Out:
# PM2.5       55.95
# PM10       122.09
# NO          10.29
# NO2         27.21
# NOx         26.66
# NH3         23.59
# CO           0.91
# SO2          8.95
# O3          30.84
# Benzene      1.21
# Toluene      4.33
# Xylene       0.40
# AQI        132.00
# dtype: float64

# %%
x.median(numeric_only=True)
# Out:
# PM2.5       55.95
# PM10       122.09
# NO          10.29
# NO2         27.21
# NOx         26.66
# NH3         23.59
# CO           0.91
# SO2          8.95
# O3          30.84
# Benzene      1.21
# Toluene      4.33
# Xylene       0.40
# AQI        132.00
# dtype: float64

# %%
x.fillna(x.median(numeric_only=True))
# Out:
#        StationId        Date  PM2.5    PM10     NO     NO2     NOx    NH3  \
# 0          AP001  2017-11-24  71.36  115.75   1.75   20.65   12.40  12.19
# 1          AP001  2017-11-25  81.40  124.50   1.44   20.50   12.08  10.72
# 2          AP001  2017-11-26  78.32  129.06   1.26   26.00   14.85  10.28
# 3          AP001  2017-11-27  88.76  135.32   6.60   30.85   21.77  12.91
# 4          AP001  2017-11-28  64.18  104.09   2.56   28.07   17.01  11.42
# ...          ...         ...    ...     ...    ...     ...     ...    ...
# 108030     WB013  2020-06-27   8.65   16.46  10.29   27.21   26.66  23.59
# 108031     WB013  2020-06-28  11.80   18.47  10.29   27.21   26.66  23.59
# 108032     WB013  2020-06-29  18.60   32.26  13.65  200.87  214.20  11.40
# 108033     WB013  2020-06-30  16.07   39.30   7.56   29.13   36.69  29.26
# 108034     WB013  2020-07-01  10.50   36.50   7.78   22.50   30.25  27.23
#
#           CO    SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# ...

# %%
x.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  86410.000000  65329.000000  90929.000000  91488.000000  92535.000000
# mean      80.272571    157.968427     23.123424     35.240760     41.195055
# std       76.526403    123.418672     34.491019     29.510827     45.145976
# min        0.020000      0.010000      0.010000      0.010000      0.000000
# 25%       31.880000     70.150000      4.840000     15.090000     13.970000
# 50%       55.950000    122.090000     10.290000     27.210000     26.660000
# 75%       99.920000    208.670000     24.980000     46.930000     50.500000
# max     1000.000000   1000.000000    470.000000    448.050000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  59930.000000  95037.000000  82831.000000  82467.000000  76580.000000
# mean      28.732875      1.605749     12.257634     38.134836      3.358029
# ...

# %%
import seaborn as sns
sns.displot(x['Toluene'])

# %%
sns.boxplot(x['Toluene'])
# Out:
# <Axes: ylabel='Toluene'>
