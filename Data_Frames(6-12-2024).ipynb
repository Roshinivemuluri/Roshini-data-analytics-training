# %% [markdown]
# <a href="https://colab.research.google.com/github/Roshinivemuluri/Roshini-data-analytics-training/blob/main/Data_Frames(6-12-2024).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = pd.read_csv('/content/dataset.csv')

# %%
x
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# ...

# %%
print(x.loc[x.index[:5]])  # Slice the index and use it to select rows
# Out:
#                      cnt   t1   t2    hum  wind_speed  is_holiday  is_weekend  \
# timestamp
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0         0.0         1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0         0.0         1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0         0.0         1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5         0.0         1.0
# 2015-01-04 05:00:00   46  2.0  2.0   93.0         4.0         0.0         1.0
#
#                      season  cnt_diff_loc
# timestamp
# 2015-01-04 01:00:00     3.0           NaN
# 2015-01-04 02:00:00     3.0          -4.0
# 2015-01-04 03:00:00     3.0         -62.0
# 2015-01-04 04:00:00     3.0         -25.0
# 2015-01-04 05:00:00     3.0          -1.0

# %%
print(x.iloc[10:15]) # iloc uses integer positions, so it remains unchanged
# Out:
#                       cnt   t1   t2    hum  wind_speed  is_holiday  \
# timestamp
# 2015-01-04 11:00:00   727  2.0 -1.5  100.0        12.0         0.0
# 2015-01-04 12:00:00   862  2.0 -1.5   96.5        13.0         0.0
# 2015-01-04 13:00:00   916  3.0 -0.5   87.0        15.0         0.0
# 2015-01-04 14:00:00  1039  2.5  0.0   90.0         8.0         0.0
# 2015-01-04 15:00:00   869  2.0 -1.5   93.0        11.0         0.0
#
#                      is_weekend  season  cnt_diff_loc
# timestamp
# 2015-01-04 11:00:00         1.0     3.0         199.0
# 2015-01-04 12:00:00         1.0     3.0         135.0
# 2015-01-04 13:00:00         1.0     3.0          54.0
# 2015-01-04 14:00:00         1.0     3.0         123.0
# 2015-01-04 15:00:00         1.0     3.0        -170.0

# %%
x.drop('t2', axis=1)
# Out:
#                       cnt   t1    hum  wind_speed  is_weekend  season
# timestamp
# 2015-01-04 02:00:00   134  2.5   96.5         0.0         1.0     3.0
# 2015-01-04 03:00:00    72  2.0  100.0         0.0         1.0     3.0
# 2015-01-04 04:00:00    47  2.0   93.0         6.5         1.0     3.0
# 2015-01-04 05:00:00    46  2.0   93.0         4.0         1.0     3.0
# 2015-01-04 06:00:00    51  1.0  100.0         7.0         1.0     3.0
# ...                   ...  ...    ...         ...         ...     ...
# 2017-01-03 19:00:00  1042  5.0   81.0        19.0         0.0     3.0
# 2017-01-03 20:00:00   541  5.0   81.0        21.0         0.0     3.0
# 2017-01-03 21:00:00   337  5.5   78.5        24.0         0.0     3.0
# 2017-01-03 22:00:00   224  5.5   76.0        23.0         0.0     3.0
# 2017-01-03 23:00:00   139  5.0   76.0        22.0         0.0     3.0
#
# [17412 rows x 6 columns]

# %%
x.drop(x.index[0], axis=0)
# Out:
#                       cnt   t1   t2    hum  wind_speed  is_weekend  season
# timestamp
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0         1.0     3.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5         1.0     3.0
# 2015-01-04 05:00:00    46  2.0  2.0   93.0         4.0         1.0     3.0
# 2015-01-04 06:00:00    51  1.0 -1.0  100.0         7.0         1.0     3.0
# 2015-01-04 07:00:00    75  1.0 -1.0  100.0         7.0         1.0     3.0
# ...                   ...  ...  ...    ...         ...         ...     ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0         0.0     3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0         0.0     3.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0         0.0     3.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0         0.0     3.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0         0.0     3.0
#
# [17411 rows x 7 columns]
